# %%
# !pip install torch #installing PyTorch
# Out:
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/216.1 MB ? eta -:--:--
#    ---------------------------------------- 1.6/216.1 MB 4.6 MB/s eta 0:00:47
#    ---------------------------------------- 2.6/216.1 MB 4.7 MB/s eta 0:00:46
#     --------------------------------------- 4.5/216.1 MB 6.0 MB/s eta 0:00:36
#     --------------------------------------- 5.0/216.1 MB 6.2 MB/s eta 0:00:34
#    - -------------------------------------- 6.0/216.1 MB 5.5 MB/s eta 0:00:39
#    - -------------------------------------- 7.1/216.1 MB 5.4 MB/s eta 0:00:39
#    - -------------------------------------- 7.9/216.1 MB 5.2 MB/s eta 0:00:41
#    - -------------------------------------- 8.1/216.1 MB 4.6 MB/s eta 0:00:46
#    - -------------------------------------- 8.9/216.1 MB 4.5 MB/s eta 0:00:47
#    - -------------------------------------- 10.0/216.1 MB 4.5 MB/s eta 0:00:46
# ...

# %%
import torch

# %%
data = [[1,2] ,[3,4]] #python sees this as a list and not a math object

# %%
print ("Tensor from list: \n",data)
# Out:
# Tensor from list:
#  [[1, 2], [3, 4]]

# %%
x_data= torch.tensor(data)#converts list into tensor

# %%
print ("Tensor from list: \n",x_data)
# Out:
# Tensor from list:
#  tensor([[1, 2],
#         [3, 4]])

# %%
#its not a list anymore,its something pytorch can use for AI and machine learning

# %%
x_ran =torch.rand(2,3)

# %%
# x_rand() creates a tensor with random numbers
(2,3) means 2 rows and 3 columns

# %%
print("Random tensor:\n",x_ran)
# Out:
# Random tensor:
#  tensor([[0.9340, 0.6183, 0.9421],
#         [0.1773, 0.8445, 0.1905]])
